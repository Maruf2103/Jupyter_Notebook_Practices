# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"E:\3rdyear\2nd_sem\3200\New folder\polynomial.csv")
dataset.head(3)
# Out:
#    Age  Experience  Salary
# 0   37           6   34638
# 1   44          19  211476
# 2   57          28  420310

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
dataset.corr()
# Out:
#                  Age  Experience    Salary
# Age         1.000000    0.951026  0.933860
# Experience  0.951026    1.000000  0.971564
# Salary      0.933860    0.971564  1.000000

# %%
plt.scatter(dataset["Age"],dataset["Salary"])
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["Salary"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf=PolynomialFeatures(degree=2)
pf.fit(x)
k=pf.transform(x)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 91.22855498753039
