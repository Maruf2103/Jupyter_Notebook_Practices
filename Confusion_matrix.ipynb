# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv(r"E:\3rdyear\2nd_sem\3200\datafiles\classification_dataset.csv")

# %%
dataset.head(5)
# Out:
#    age  income education_level  hours_worked_per_week marital_status  \
# 0   56    90.3             Low                     51        Married
# 1   46    56.4          Medium                     40         Single
# 2   32   117.2          Medium                     35        Married
# 3   60   116.2             Low                     40        Married
# 4   25    45.2            High                     30       Divorced
#
#    purchased job_category
# 0          0            D
# 1          0            B
# 2          1            D
# 3          1            D
# 4          1            D

# %%
x =dataset[['age','income']]

# %%
y= dataset['purchased']

# %%
 from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=40,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.6

# %%
from sklearn.metrics import confusion_matrix,precision_score,recall_score,f1_score

# %%
g= confusion_matrix(y_test,lr.predict(x_test))

# %%
sns.heatmap(g,annot=True)
plt.show()

# %%
precision_score(y_test,lr.predict(x_test))*100
# Out:
# 67.85714285714286

# %%
recall_score(y_test,lr.predict(x_test))*100
# Out:
# 73.07692307692307

# %%
f1_score(y_test,lr.predict(x_test))*100
# Out:
# 70.37037037037037
