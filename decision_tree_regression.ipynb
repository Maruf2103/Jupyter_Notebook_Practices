# %%
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

# %%
dt= pd.read_csv(r"E:\3rdyear\2nd_sem\3200\datafiles\age_salary_dataset.csv")

# %%
dt.head(5)
# Out:
#    age  salary
# 0   61   44397
# 1   28   26142
# 2   22   29307
# 3   58   85809
# 4   42   97660

# %%
dt.isnull()
# Out:
#        age  salary
# 0    False   False
# 1    False   False
# 2    False   False
# 3    False   False
# 4    False   False
# ..     ...     ...
# 495  False   False
# 496  False   False
# 497  False   False
# 498  False   False
# 499  False   False
#
# [500 rows x 2 columns]

# %%
dt.isnull().sum()
# Out:
# age       0
# salary    0
# dtype: int64

# %%
sns.scatterplot(x="age",y="salary",data =dt)
plt.show()

# %%
sns.pairplot(data = dt)
plt.show()

# %%
x=dt[["age"]]
y= dt["salary"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier(criterion="entropy")
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dtc.score(x_test,y_test)
# Out:
# 0.0

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr= DecisionTreeRegressor(max_depth=3)
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
dtr.score(x_test,y_test)*100
# Out:
# 68.3145986718577

# %%
for i in range(1,20):
    dtr1 = DecisionTreeRegressor(max_depth=i)
    dtr1.fit(x_train,y_train)
    print(dtr1.score(x_test,y_test))
# Out:
# 0.44450182470090294
# 0.6967815609159425
# 0.683145986718577
# 0.6770044454317526
# 0.6744077657455063
# 0.6684477103842534
# 0.6568414117954441
# 0.6445044829212091
# 0.6457386013149782
# 0.6431579283144644
# 0.6447198047758156
# 0.6456272397492524
# 0.6456272397492524
# 0.6456272397492524
# 0.6456272397492524
# 0.6456272397492524
# 0.6456272397492524
# 0.6456272397492524
# 0.6456272397492524
