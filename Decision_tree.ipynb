# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
dataset = pd.read_csv(r"E:\3rdyear\2nd_sem\3200\datafiles\large_decision_tree_dataset.csv")

# %%
print(dataset.head())
# Out:
#     Outlook Temperature Humidity    Wind Play
# 0     Sunny        Mild     High  Strong   No
# 1  Overcast        Mild     High    Weak  Yes
# 2     Sunny        Cool   Normal  Strong  Yes
# 3  Overcast        Mild     High    Weak  Yes
# 4  Overcast        Mild   Normal  Strong  Yes

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
for col in dataset.columns:
    dataset[col] = le.fit_transform(dataset[col])

# %%
dataset.head()
# Out:
#    Outlook  Temperature  Humidity  Wind  Play
# 0        2            2         0     0     0
# 1        0            2         0     1     1
# 2        2            0         1     0     1
# 3        0            2         0     1     1
# 4        0            2         1     0     1

# %%
x = dataset.drop("Play",axis=1)
y = dataset["Play"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
dataset
# Out:
#      Outlook  Temperature  Humidity  Wind  Play
# 0          2            2         0     0     0
# 1          0            2         0     1     1
# 2          2            0         1     0     1
# 3          0            2         0     1     1
# 4          0            2         1     0     1
# ..       ...          ...       ...   ...   ...
# 495        0            1         0     0     1
# 496        2            2         1     0     1
# 497        0            2         0     1     1
# 498        0            0         0     0     1
# 499        0            2         1     0     1
#
# [500 rows x 5 columns]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(criterion="entropy",max_depth=5)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
dt.score(x_test,y_test)*100
# Out:
# 100.0

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x="Outlook",y="Temperature",data=dataset,hue="Play")
plt.show()

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
accuracy_score(y_test,dt.predict(x_test))
# Out:
# 1.0

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(dt)
plt.show()

# %%
dt1 = DecisionTreeClassifier(criterion="gini",max_depth=5)
dt1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
dt1.score(x_test,y_test)
# Out:
# 1.0
