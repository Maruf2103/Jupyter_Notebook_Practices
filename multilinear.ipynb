# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset =pd.read_csv(r"E:\3rdyear\2nd_sem\3200\New folder\multi2 .csv")
dataset.head(5)
# Out:
#    Age  Experience  Salary
# 0   50           0   42646
# 1   36          34  135075
# 2   29          13   63708
# 3   42           2   44371
# 4   40           0   32835

# %%
dataset.shape
# Out:
# (100, 3)

# %%
dataset.isnull().sum()
# Out:
# Age           0
# Experience    0
# Salary        0
# dtype: int64

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(),annot=True)
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["Salary"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9712676874398654

# %%
lr.predict(x_test)
# Out:
# array([ 95249.42029813,  81451.85835979,  96830.87023225,  97881.82643956,
#        123510.16914489,  35980.44771251, 126267.67528329,  73699.80242508,
#         74355.39614886,  34664.24464179,  96960.98585238,  87892.72684694,
#         38217.49137041, 103141.62309928,  43867.6348905 ,  29409.46360523,
#         65292.15276658, 120357.30052295, 106554.72296146, 111814.51962118])
